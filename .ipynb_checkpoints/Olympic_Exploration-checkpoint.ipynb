# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC

# %%
dataset = pd.read_csv('./data/athlete_events.csv')
dataset.info()
dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
print(dataset.describe())
print()
print(dataset.isna().sum())
print()
df = pd.DataFrame(dataset, columns=['Height', 'Team'])
df = dataset[['Height', 'Team']].sort_values(['Height'],ascending=False)


percentOfNaAge = ((dataset['Age'].isna().sum() / 271116) * 100)
percentOfNaHeight = ((dataset['Height'].isna().sum() / 271116) * 100)
percentOfNaWeight = ((dataset['Weight'].isna().sum() / 271116) * 100)
percentOfNaMedals = ((dataset['Medal'].isna().sum() / 271116) * 100)
value = {'a': percentOfNaAge, 'h': percentOfNaHeight, 'w': percentOfNaWeight, 'm': percentOfNaMedals}
print()
print('''
PercentOfNaAge: {a} 

PercentOfNaHeight: {h} 

PercentOfNaWeight: {w}

PercentOfNaMedals: {m}'
'''.format(**value))
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000
#
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64
#
#
#
# PercentOfNaAge: 3.49444518213606
#
# PercentOfNaHeight: 22.193821095029435
#
# PercentOfNaWeight: 23.19118015904631
#
# PercentOfNaMedals: 85.3262072323286'

# %%
df_describe = dataset.groupby('Team').describe()

# %%
df_describe['Age'].sort_values('mean', ascending=False)[:50]
# Out:
#                     count       mean        std   min    25%   50%    75%  \
# Team
# Pirouette-31          1.0  71.000000        NaN  71.0  71.00  71.0  71.00
# Pirouette-5           2.0  71.000000   0.000000  71.0  71.00  71.0  71.00
# Whisper               1.0  67.000000        NaN  67.0  67.00  67.0  67.00
# Ariette-8             1.0  62.000000        NaN  62.0  62.00  62.0  62.00
# Ariette-10            2.0  62.000000   0.000000  62.0  62.00  62.0  62.00
# Dow Jones             1.0  58.000000        NaN  58.0  58.00  58.0  58.00
# Cincinnati Archers    6.0  57.666667   8.213810  44.0  55.00  58.5  62.00
# Potomac Archers       4.0  57.500000   7.141428  48.0  54.00  59.5  63.00
# Sibindi-2             1.0  55.000000        NaN  55.0  55.00  55.0  55.00
# Martha-1              2.0  53.000000   0.000000  53.0  53.00  53.0  53.00
# Martha-27             1.0  53.000000        NaN  53.0  53.00  53.0  53.00
# Brentina              1.0  53.000000        NaN  53.0  53.00  53.0  53.00
# Orion                 1.0  52.000000        NaN  52.0  52.00  52.0  52.00
# Diabolo St Maurice    1.0  51.000000        NaN  51.0  51.00  51.0  51.00
# Windor                2.0  51.000000   4.242641  48.0  49.50  51.0  52.50
# Red Dragon            3.0  51.000000   4.582576  47.0  48.50  50.0  53.00
# Lett                  3.0  50.666667   9.018500  42.0  46.00  50.0  55.00
# Chicago Archers       4.0  50.500000   5.802298  43.0  48.25  51.0  53.25
# Bona Fide             2.0  50.500000   0.707107  50.0  50.25  50.5  50.75
# Greenoaks Dundee      1.0  50.000000        NaN  50.0  50.00  50.0  50.00
# Hirondelle            2.0  50.000000  14.142136  40.0  45.00  50.0  55.00
# Laurea-1              1.0  50.000000        NaN  50.0  50.00  50.0  50.00
# Rika II               3.0  49.666667  13.650397  34.0  45.00  56.0  57.50
# Springbok             1.0  49.000000        NaN  49.0  49.00  49.0  49.00
# Mignon-29             1.0  49.000000        NaN  49.0  49.00  49.0  49.00
# Mignon-3              2.0  49.000000   0.000000  49.0  49.00  49.0  49.00
# Favorite-17           3.0  48.666667   5.686241  44.0  45.50  47.0  51.00
# Favorite-1            6.0  48.666667   5.085928  44.0  44.75  47.0  53.00
# Notavel               1.0  48.000000        NaN  48.0  48.00  48.0  48.00
# Alain IV              3.0  48.000000   7.211103  40.0  45.00  50.0  52.00
# Twinkle               2.0  47.500000   0.707107  47.0  47.25  47.5  47.75
# Gustl XI              3.0  47.333333   4.163332  44.0  45.00  46.0  49.00
# Acipactli             3.0  47.333333   4.163332  44.0  45.00  46.0  49.00
# Heroine               3.0  47.000000   7.000000  42.0  43.00  44.0  49.50
# Gilliatt V            1.0  47.000000        NaN  47.0  47.00  47.0  47.00
# Ballerina IV          3.0  47.000000  11.357817  34.0  43.00  52.0  53.50
# Briar                 1.0  47.000000        NaN  47.0  47.00  47.0  47.00
# Ciss                  1.0  47.000000        NaN  47.0  47.00  47.0  47.00
# May Be VII            5.0  46.600000  12.095454  32.0  37.00  48.0  55.00
# Gallia II             5.0  46.400000   6.503845  38.0  41.00  49.0  52.00
# Bonaparte             1.0  46.000000        NaN  46.0  46.00  46.0  46.00
# Clearwater            1.0  46.000000        NaN  46.0  46.00  46.0  46.00
# Freddy                2.0  46.000000   4.242641  43.0  44.50  46.0  47.50
# Camille               1.0  46.000000        NaN  46.0  46.00  46.0  46.00
# Bonzo                 3.0  46.000000   4.358899  43.0  43.50  44.0  47.50
# Ralia                 5.0  45.800000   8.348653  36.0  41.00  43.0  54.00
# Astrid III            3.0  45.666667   9.237604  35.0  43.00  51.0  51.00
# Hollandia             6.0  45.500000   4.460942  38.0  44.00  46.0  48.75
# Three Star Too        2.0  45.500000   3.535534  43.0  44.25  45.5  46.75
# Ali-Baba IX           2.0  45.500000  10.606602  38.0  41.75  45.5  49.25
#
#                      max
# Team
# Pirouette-31        71.0
# Pirouette-5         71.0
# Whisper             67.0
# Ariette-8           62.0
# Ariette-10          62.0
# Dow Jones           58.0
# Cincinnati Archers  68.0
# Potomac Archers     63.0
# Sibindi-2           55.0
# Martha-1            53.0
# Martha-27           53.0
# Brentina            53.0
# Orion               52.0
# Diabolo St Maurice  51.0
# Windor              54.0
# Red Dragon          56.0
# Lett                60.0
# Chicago Archers     57.0
# Bona Fide           51.0
# Greenoaks Dundee    50.0
# Hirondelle          60.0
# Laurea-1            50.0
# Rika II             59.0
# Springbok           49.0
# Mignon-29           49.0
# Mignon-3            49.0
# Favorite-17         55.0
# Favorite-1          55.0
# Notavel             48.0
# Alain IV            54.0
# Twinkle             48.0
# Gustl XI            52.0
# Acipactli           52.0
# Heroine             55.0
# Gilliatt V          47.0
# Ballerina IV        55.0
# Briar               47.0
# Ciss                47.0
# May Be VII          61.0
# Gallia II           52.0
# Bonaparte           46.0
# Clearwater          46.0
# Freddy              49.0
# Camille             46.0
# Bonzo               51.0
# Ralia               55.0
# Astrid III          51.0
# Hollandia           50.0
# Three Star Too      48.0
# Ali-Baba IX         53.0

# %%
dataset[['Age','Team']].groupby('Team').Age.apply(lambda x: x.mode())[:50]
# Out:
# Team
# 30. Februar                   0    23.0
#                               1    44.0
# A North American Team         0    38.0
#                               1    42.0
#                               2    44.0
# Acipactli                     0    44.0
#                               1    46.0
#                               2    52.0
# Acturus                       0    27.0
# Afghanistan                   0    20.0
# Akatonbo                      0    36.0
#                               1    41.0
#                               2    44.0
# Alain IV                      0    40.0
#                               1    50.0
#                               2    54.0
# Albania                       0    21.0
# Alcaid                        0    28.0
#                               1    29.0
#                               2    33.0
# Aldebaran                     0    25.0
#                               1    40.0
# Aldebaran II                  0    36.0
#                               1    39.0
# Aletta                        0    26.0
#                               1    31.0
#                               2    40.0
# Algeria                       0    23.0
# Ali-Baba II                   0    51.0
# Ali-Baba IV                   0    35.0
#                               1    41.0
# Ali-Baba IX                   0    38.0
#                               1    53.0
# Ali-Baba VI                   0    33.0
#                               1    49.0
# Allegro                       0    30.0
#                               1    38.0
# Almaz                         0    24.0
#                               1    27.0
# Aloha II                      0    16.0
#                               1    23.0
#                               2    39.0
#                               3    43.0
# Amateur Athletic Association  0    23.0
# American Samoa                0    19.0
# Amolgavar                     0    22.0
#                               1    24.0
#                               2    36.0
# Amstel Amsterdam              0    20.0
#                               1    21.0
# Name: Age, dtype: float64

# %%
dataset['Age'].groupby(dataset['Age']).count().sort_values(ascending=False)[:60]
# Out:
# Age
# 23.0    21875
# 24.0    21720
# 22.0    20814
# 25.0    19707
# 21.0    19164
# 26.0    17675
# 27.0    16025
# 20.0    15258
# 28.0    14043
# 19.0    11643
# 29.0    11463
# 30.0     9488
# 18.0     8152
# 31.0     7559
# 32.0     6246
# 17.0     5376
# 33.0     4800
# 34.0     3985
# 16.0     3852
# 35.0     3133
# 36.0     2503
# 15.0     2203
# 37.0     1953
# 38.0     1612
# 39.0     1405
# 40.0     1210
# 41.0      953
# 42.0      866
# 14.0      837
# 43.0      793
# 44.0      683
# 45.0      584
# 46.0      429
# 47.0      408
# 48.0      407
# 49.0      362
# 50.0      278
# 52.0      244
# 53.0      200
# 51.0      199
# 13.0      187
# 54.0      162
# 56.0      131
# 55.0      104
# 60.0       88
# Name: Age, dtype: int64

# %%
dataset['Age'].mode()
# Out:
# 0    23.0
# dtype: float64
